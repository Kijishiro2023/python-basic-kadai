# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for planet in array :
    print(planet)

i = 0
while i != 8 :
    print(array[i])
    i = i + 1

print(array[i])  # 最後の要素
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
