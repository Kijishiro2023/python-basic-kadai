# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  # メソッドを定義する
  def printinfo(self):
    print("名前 ", self.name)
    print("年齢 ", self.age)

# インスタンス化する
samurai= Human("侍太郎", 35)

# メソッドにアクセスして実行する
samurai.printinfo()
# Out:
# 名前  侍太郎
# 年齢  35
